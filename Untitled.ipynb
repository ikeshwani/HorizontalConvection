# %%
from IPython.display import Video

#Video("code/HorizontalConvection/animations/shear_instability_example.mp4", embed=True)
Video.from_file("code/HorizontalConvection/animations/shear_instability_example.mp4")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4
#       1 from IPython.display import Video
#       3 #Video("code/HorizontalConvection/animations/shear_instability_example.mp4", embed=True)
# ----> 4 Video.from_file("code/HorizontalConvection/animations/shear_instability_example.mp4")
#
# AttributeError: type object 'Video' has no attribute 'from_file'

# %%
from IPython.display import HTML

HTML("""
    <video width="320" height="240" controls>
        <source src=""../animations/shear_instability_example.mp4"" type="video/mp4">
    </video>
""")
# Out:
#     <video width="320" height="240" controls>
#         <source src=""../animations/shear_instability_example.mp4"" type="video/mp4">
#     </video>

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="code/HorizontalConvection/animations/thc_buoyancy_movie.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="code/HorizontalConvection/animations/thc_buoyancy_movie.mp4" type="video/mp4">
# </video>
